# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
iris = pd.read_csv('IRIS.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
n = len(iris[iris['species'] == 'Iris-setosa'])
print('No of Iris-setosa is:',n)
# Out:
# No of Iris-setosa is: 50

# %%
n = len(iris[iris['species'] == 'Iris-versicolor'])
print('No of Iris-versicolor is:',n)
# Out:
# No of Iris-versicolor is: 50

# %%
n = len(iris[iris['species'] == 'Iris-virginica'])
print('No of Iris-verginica is:',n)
# Out:
# No of Iris-verginica is: 50

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.set_style('darkgrid')
sns.set_palette('gist_earth')

# %%
sns.pairplot(data = iris,hue = 'species')

# %%
sns.set_palette('Set1_r')

# %%
sns.jointplot(data =iris,x = 'sepal_length',y = 'sepal_width')

# %%
sns.catplot(data=iris, x="species", y="sepal_length",palette = 'Set1')

# %%
sns.catplot(data=iris, x="species", y="sepal_width",palette = 'rainbow_r')

# %%
sns.catplot(data=iris, x="species", y="petal_width")

# %%
sns.catplot(data=iris, x="species", y="petal_length",palette = 'RdYlGn')

# %%
sns.jointplot(data = iris,x = 'petal_length',y = 'petal_width')

# %%
iris_setosa = iris[iris['species'] == 'Iris-setosa']

# %%
sns.set_palette('Set1_r')

# %%
sns.kdeplot(x = iris_setosa['sepal_length'],y = iris_setosa['sepal_width'],shade = True,cmap = 'autumn_r')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.set_palette('rocket')

# %%
iris_virginica = iris[iris['species'] == 'Iris-virginica']
sns.kdeplot(x = iris_virginica['sepal_length'],y = iris_virginica['sepal_width'],shade = True,cmap = 'rocket_r')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.set_palette('plasma')

# %%
iris_versicolor = iris[iris['species'] == 'Iris-versicolor']
sns.kdeplot(x = iris_versicolor['sepal_length'],y = iris_versicolor['sepal_width'],shade = True,cmap = 'plasma')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
corr_mat = iris.corr()
corr_mat
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(iris.corr(),annot = True,square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Training & Prediction

# %%
from sklearn.model_selection import train_test_split

# %%
X = iris.drop('species',axis = 1)
y = iris['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()

# %%
svm_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
predict_svm = svm_model.predict(X_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix

# %%
print(classification_report(y_test,predict_svm))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      0.95      0.97        20
#  Iris-virginica       0.92      1.00      0.96        12
#
#        accuracy                           0.98        45
#       macro avg       0.97      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %%
print(confusion_matrix(y_test,predict_svm))
# Out:
# [[13  0  0]
#  [ 0 19  1]
#  [ 0  0 12]]

# %%
from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,predict_svm))
# Out:
# Accuracy Score: 0.9777777777777777

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predict_lg = log_model.predict(X_test)

# %%
print(classification_report(y_test,predict_lg))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      0.95      0.97        20
#  Iris-virginica       0.92      1.00      0.96        12
#
#        accuracy                           0.98        45
#       macro avg       0.97      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %%
print(confusion_matrix(y_test,predict_lg))
# Out:
# [[13  0  0]
#  [ 0 19  1]
#  [ 0  0 12]]

# %%
print("Accuracy Score:",accuracy_score(y_test,predict_lg))
# Out:
# Accuracy Score: 0.9777777777777777

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predict_dtree = dtree.predict(X_test)

# %%
print("Accuracy Score:",accuracy_score(y_test,predict_dtree))
# Out:
# Accuracy Score: 0.9555555555555556

# %%
print(classification_report(y_test,predict_dtree))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.95      0.95      0.95        20
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45

# %%
print(confusion_matrix(y_test,predict_dtree))
# Out:
# [[13  0  0]
#  [ 0 19  1]
#  [ 0  1 11]]

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(X_test)

# %%
print("Accuracy Score:",accuracy_score(y_test,predict_rfc))
# Out:
# Accuracy Score: 0.9555555555555556

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.95      0.95      0.95        20
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45

# %%
print(confusion_matrix(y_test,predict_rfc))
# Out:
# [[13  0  0]
#  [ 0 19  1]
#  [ 0  1 11]]

# %% [markdown]
# # KNN Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predict_knn = knn.predict(X_test)

# %%
print("Accuracy Score:",accuracy_score(y_test,predict_knn))
# Out:
# Accuracy Score: 1.0

# %%
print(classification_report(y_test,predict_knn))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      1.00      1.00        20
#  Iris-virginica       1.00      1.00      1.00        12
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %%
print(confusion_matrix(y_test,predict_knn))
# Out:
# [[13  0  0]
#  [ 0 20  0]
#  [ 0  0 12]]

# %% [markdown]
# # GausianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
predict_gnb = gnb.predict(X_test)

# %%
print("Accuracy Score:",accuracy_score(y_test,predict_gnb))
# Out:
# Accuracy Score: 0.9555555555555556

# %%
print(classification_report(y_test,predict_gnb))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.95      0.95      0.95        20
#  Iris-virginica       0.92      0.92      0.92        12
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45

# %%
print(confusion_matrix(y_test,predict_gnb))
# Out:
# [[13  0  0]
#  [ 0 19  1]
#  [ 0  1 11]]

# %%
df = pd.DataFrame({'Model':['SVM','Random Forest','Decision Tree','KNN','Naive Bayes','Logistic Regression'],
                 'Accuracy' : [0.978,0.956,0.956,1,0.956,0.978]})
results= df.sort_values(ascending = False,by = 'Accuracy')
results_df = results.set_index('Accuracy')

# %%
results_df
# Out:
#                         Model
# Accuracy
# 1.000                     KNN
# 0.978                     SVM
# 0.978     Logistic Regression
# 0.956           Random Forest
# 0.956           Decision Tree
# 0.956             Naive Bayes
